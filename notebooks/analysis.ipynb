# %%
import pandas as pd

df = pd.read_csv("../data/csv/birds_occurrences.csv")

# %%
# Top 20 species
df["species"].value_counts().head(20)
# Out:
# species
# Parus major                   45
# Turdus merula                 42
# Cyanistes caeruleus           40
# Fringilla coelebs             32
# Erithacus rubecula            30
# Anas platyrhynchos            30
# Podiceps cristatus            26
# Cygnus olor                   26
# Corvus corone                 25
# Fulica atra                   25
# Phalacrocorax carbo           25
# Chroicocephalus ridibundus    23
# Larus michahellis             22
# Chloris chloris               21
# Mareca strepera               19
# Ardea cinerea                 19
# Aythya fuligula               19
# Spinus spinus                 18
# Passer domesticus             18
# Motacilla alba                18
# Name: count, dtype: int64

# %%
# Occurrences per year
df["year"].value_counts().sort_index()
# Out:
# year
# 2015    1000
# Name: count, dtype: int64

# %%
# Records without species identification
df["species"].isna().sum()
# Out:
# np.int64(0)

# %%
df["media_url"].isna().sum()
# Out:
# np.int64(1000)
